# %% [markdown]
# ## **ZUBIN JAMES PALIT (20BEC0088)**
#
# ---
# # ASSIGNMENT - 3

# %%
#UPLOADING DATA SET FROM DRIVE
#GIVING DRIVE ACCESS TO COLAB
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_gen=ImageDataGenerator(rescale=(1./255),horizontal_flip=True,shear_range=0.2)
test_gen=ImageDataGenerator(rescale=(1./255))

# %%
train=train_gen.flow_from_directory('/content/gdrive/MyDrive/BIRDS/train_data/train_data', target_size=(120,120),class_mode='categorical',batch_size=8)
test=test_gen.flow_from_directory('/content/gdrive/MyDrive/BIRDS/test_data/test_data', target_size=(120,120),class_mode='categorical',batch_size=8)
# Out:
# Found 150 images belonging to 16 classes.
# Found 157 images belonging to 16 classes.

# %%
train.class_indices
# Out:
# {'blasti': 0,
#  'bonegl': 1,
#  'brhkyt': 2,
#  'cbrtsh': 3,
#  'cmnmyn': 4,
#  'gretit': 5,
#  'hilpig': 6,
#  'himbul': 7,
#  'himgri': 8,
#  'hsparo': 9,
#  'indvul': 10,
#  'jglowl': 11,
#  'lbicrw': 12,
#  'mgprob': 13,
#  'rebimg': 14,
#  'wcrsrt': 15}

# %%
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Convolution2D(20,(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(45,activation='relu'))
model.add(Dense(16,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train,batch_size=8,validation_data=test,epochs=10)
# Out:
# Epoch 1/10
# 19/19 [==============================] - 446s 24s/step - loss: 3.5715 - accuracy: 0.0600 - val_loss: 2.7704 - val_accuracy: 0.0573
# Epoch 2/10
# 19/19 [==============================] - 129s 7s/step - loss: 2.6132 - accuracy: 0.1867 - val_loss: 2.6608 - val_accuracy: 0.1274
# Epoch 3/10
# 19/19 [==============================] - 105s 6s/step - loss: 2.4817 - accuracy: 0.2467 - val_loss: 2.6961 - val_accuracy: 0.1401
# Epoch 4/10
# 19/19 [==============================] - 135s 7s/step - loss: 2.4059 - accuracy: 0.3000 - val_loss: 2.6408 - val_accuracy: 0.1911
# Epoch 5/10
# 19/19 [==============================] - 131s 7s/step - loss: 2.2536 - accuracy: 0.3200 - val_loss: 2.6581 - val_accuracy: 0.1338
# Epoch 6/10
# 19/19 [==============================] - 128s 7s/step - loss: 2.1332 - accuracy: 0.3667 - val_loss: 2.7519 - val_accuracy: 0.1401
# Epoch 7/10
# 19/19 [==============================] - 128s 7s/step - loss: 2.0214 - accuracy: 0.3533 - val_loss: 2.7315 - val_accuracy: 0.1274
# Epoch 8/10
# 19/19 [==============================] - 129s 7s/step - loss: 1.9641 - accuracy: 0.4000 - val_loss: 2.6988 - val_accuracy: 0.1465
# Epoch 9/10
# 19/19 [==============================] - 130s 7s/step - loss: 1.8518 - accuracy: 0.4000 - val_loss: 2.7715 - val_accuracy: 0.1529
# Epoch 10/10
# 19/19 [==============================] - 128s 7s/step - loss: 1.7934 - accuracy: 0.4000 - val_loss: 2.6812 - val_accuracy: 0.2102

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 118, 118, 20)      560
#
#  max_pooling2d (MaxPooling2D  (None, 59, 59, 20)       0
#  )
#
#  flatten (Flatten)           (None, 69620)             0
#
#  dense (Dense)               (None, 45)                3132945
#
#  dense_1 (Dense)             (None, 16)                736
#
# =================================================================
# Total params: 3,134,241
# Trainable params: 3,134,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Convolution2D(12,(3,3),activation='relu',input_shape=(120, 120, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Convolution2D(24,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Convolution2D(36,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(62,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 118, 118, 12)      336
#
#  max_pooling2d_4 (MaxPooling  (None, 59, 59, 12)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 57, 57, 24)        2616
#
#  max_pooling2d_5 (MaxPooling  (None, 28, 28, 24)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 36)        7812
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 36)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6084)              0
#
#  dense_5 (Dense)             (None, 62)                377270
#
#  dense_6 (Dense)             (None, 32)                2016
#
#  dense_7 (Dense)             (None, 16)                528
#
# =================================================================
# Total params: 390,578
# Trainable params: 390,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train,batch_size=8,validation_data=test,epochs=25)
# Out:
# Epoch 1/25
# 19/19 [==============================] - 113s 6s/step - loss: 2.7741 - accuracy: 0.1133 - val_loss: 2.7270 - val_accuracy: 0.1592
# Epoch 2/25
# 19/19 [==============================] - 129s 7s/step - loss: 2.6259 - accuracy: 0.2000 - val_loss: 2.6470 - val_accuracy: 0.1847
# Epoch 3/25
# 19/19 [==============================] - 128s 7s/step - loss: 2.4751 - accuracy: 0.2067 - val_loss: 2.6012 - val_accuracy: 0.1656
# Epoch 4/25
# 19/19 [==============================] - 128s 7s/step - loss: 2.3575 - accuracy: 0.2600 - val_loss: 2.6515 - val_accuracy: 0.2102
# Epoch 5/25
# 19/19 [==============================] - 109s 6s/step - loss: 2.2103 - accuracy: 0.2533 - val_loss: 2.5853 - val_accuracy: 0.1656
# Epoch 6/25
# 19/19 [==============================] - 128s 7s/step - loss: 2.1136 - accuracy: 0.3133 - val_loss: 2.6607 - val_accuracy: 0.2739
# Epoch 7/25
# 19/19 [==============================] - 128s 7s/step - loss: 2.0600 - accuracy: 0.3133 - val_loss: 2.5761 - val_accuracy: 0.2102
# Epoch 8/25
# 19/19 [==============================] - 128s 7s/step - loss: 1.9810 - accuracy: 0.3533 - val_loss: 2.4599 - val_accuracy: 0.2739
# Epoch 9/25
# 19/19 [==============================] - 130s 7s/step - loss: 1.7845 - accuracy: 0.3600 - val_loss: 2.6620 - val_accuracy: 0.2420
# Epoch 10/25
# 19/19 [==============================] - 131s 7s/step - loss: 1.6877 - accuracy: 0.4400 - val_loss: 2.4980 - val_accuracy: 0.2930
# Epoch 11/25
# 19/19 [==============================] - 128s 7s/step - loss: 1.5278 - accuracy: 0.4733 - val_loss: 2.8162 - val_accuracy: 0.2484
# Epoch 12/25
# 19/19 [==============================] - 128s 7s/step - loss: 1.4952 - accuracy: 0.4400 - val_loss: 2.6652 - val_accuracy: 0.2739
# Epoch 13/25
# 19/19 [==============================] - 128s 7s/step - loss: 1.2954 - accuracy: 0.6000 - val_loss: 2.8465 - val_accuracy: 0.2420
# Epoch 14/25
# 19/19 [==============================] - 129s 7s/step - loss: 1.1784 - accuracy: 0.5467 - val_loss: 2.9498 - val_accuracy: 0.2229
# Epoch 15/25
# 19/19 [==============================] - 130s 7s/step - loss: 1.1207 - accuracy: 0.6200 - val_loss: 3.0925 - val_accuracy: 0.2803
# Epoch 16/25
# 19/19 [==============================] - 106s 6s/step - loss: 1.0735 - accuracy: 0.6400 - val_loss: 3.1538 - val_accuracy: 0.2739
# Epoch 17/25
# 19/19 [==============================] - 128s 7s/step - loss: 0.8760 - accuracy: 0.6867 - val_loss: 3.3273 - val_accuracy: 0.2611
# Epoch 18/25
# 19/19 [==============================] - 128s 7s/step - loss: 0.7480 - accuracy: 0.7600 - val_loss: 3.6058 - val_accuracy: 0.2675
# Epoch 19/25
# 19/19 [==============================] - 129s 7s/step - loss: 0.7646 - accuracy: 0.7733 - val_loss: 3.6812 - val_accuracy: 0.2739
# Epoch 20/25
# 19/19 [==============================] - 134s 7s/step - loss: 0.7823 - accuracy: 0.7467 - val_loss: 3.5681 - val_accuracy: 0.2803
# Epoch 21/25
# 19/19 [==============================] - 127s 7s/step - loss: 0.9338 - accuracy: 0.6800 - val_loss: 3.3860 - val_accuracy: 0.2803
# Epoch 22/25
# 19/19 [==============================] - 128s 7s/step - loss: 0.5265 - accuracy: 0.8200 - val_loss: 3.8133 - val_accuracy: 0.2739
# Epoch 23/25
# 19/19 [==============================] - 128s 7s/step - loss: 0.4189 - accuracy: 0.8667 - val_loss: 4.1269 - val_accuracy: 0.2994
# Epoch 24/25
# 19/19 [==============================] - 130s 7s/step - loss: 0.3267 - accuracy: 0.8933 - val_loss: 4.4043 - val_accuracy: 0.2994
# Epoch 25/25
# 19/19 [==============================] - 129s 7s/step - loss: 0.3825 - accuracy: 0.8733 - val_loss: 4.5233 - val_accuracy: 0.2866

# %%
# Testing

import numpy as np
from tensorflow.keras.preprocessing import image

# %%
# Testing 1
img1 = image.load_img('/content/pigeon.jpg',target_size=(120,120))
img1
# Out:
# <PIL.Image.Image image mode=RGB size=120x120 at 0x7FCA600DD3F0>

# %%
img1 = image.img_to_array(img1)
img1 = np.expand_dims(img1,axis=0)
pred = np.argmax(model.predict(img1))
print(pred)
output = ['blasti','bonegl','brhkyt', 'cbrtsh', 'cmnmyn', 'gretit', 'hilpig', 'himbul', 'himgri', 'hsparo', 'indvul', 'jglowl', 'lbicrw', 'mgprob', 'rebimg', 'wcrsrt']
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1
# bonegl

# %%
# Testing 2
img2 = image.load_img('/content/_D32_10251.jpg',target_size=(120,120))
img2
# Out:
# <PIL.Image.Image image mode=RGB size=120x120 at 0x7FCA52AEFC70>

# %%
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2,axis=0)
pred = np.argmax(model.predict(img2))
print(pred)
output = ['blasti','bonegl','brhkyt', 'cbrtsh', 'cmnmyn', 'gretit', 'hilpig', 'himbul', 'himgri', 'hsparo', 'indvul', 'jglowl', 'lbicrw', 'mgprob', 'rebimg', 'wcrsrt']
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 8
# himgri

# %%
# Testing 3
img3 = image.load_img('/content/gdrive/MyDrive/BIRDS/train_data/train_data/blasti/DSC_6382.jpg',target_size=(120,120))
img3
# Out:
# <PIL.Image.Image image mode=RGB size=120x120 at 0x7FCA604A5570>

# %%
img3 = image.img_to_array(img3)
img3 = np.expand_dims(img3,axis=0)
pred = np.argmax(model.predict(img3))
print(pred)
output = ['blasti','bonegl','brhkyt', 'cbrtsh', 'cmnmyn', 'gretit', 'hilpig', 'himbul', 'himgri', 'hsparo', 'indvul', 'jglowl', 'lbicrw', 'mgprob', 'rebimg', 'wcrsrt']
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 15
# wcrsrt
